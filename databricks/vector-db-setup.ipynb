# %%
# %pip install python-dotenv pinecone_haystack haystack-ai markdown-it-py mdit_plain chromadb pinecone boto3 chroma-haystack
# Out:
# Requirement already satisfied: python-dotenv in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: pinecone_haystack in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (5.0.0)
# Requirement already satisfied: haystack-ai in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (2.11.2)
# Requirement already satisfied: markdown-it-py in /databricks/python3/lib/python3.12/site-packages (2.2.0)
# Requirement already satisfied: mdit_plain in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: chromadb in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (0.6.3)
# Requirement already satisfied: pinecone in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (6.0.2)
# Requirement already satisfied: boto3 in /databricks/python3/lib/python3.12/site-packages (1.34.69)
# Requirement already satisfied: chroma-haystack in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: haystack-experimental in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from haystack-ai) (0.8.0)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (3.1.4)
# Requirement already satisfied: jsonschema in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (4.19.2)
# Requirement already satisfied: lazy-imports in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from haystack-ai) (0.4.0)
# Requirement already satisfied: more-itertools in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from haystack-ai) (10.6.0)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (3.2.1)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (1.26.4)
# Requirement already satisfied: openai>=1.56.1 in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (1.59.6)
# Requirement already satisfied: posthog!=3.12.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from haystack-ai) (3.21.0)
# Requirement already satisfied: pydantic in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (2.8.2)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (6.0.1)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from haystack-ai) (9.0.0)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.7 in /databricks/python3/lib/python3.12/site-packages (from haystack-ai) (4.11.0)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.12/site-packages (from markdown-it-py) (0.1.0)
# Requirement already satisfied: build>=1.0.3 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /databricks/python3/lib/python3.12/site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /databricks/python3/lib/python3.12/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /databricks/python3/lib/python3.12/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /databricks/python3/lib/python3.12/site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /databricks/python3/lib/python3.12/site-packages (from chromadb) (3.10.14)
# Requirement already satisfied: httpx>=0.27.0 in /databricks/python3/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /databricks/python3/lib/python3.12/site-packages (from chromadb) (13.3.5)
# Requirement already satisfied: certifi>=2019.11.17 in /databricks/python3/lib/python3.12/site-packages (from pinecone) (2024.6.2)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.5 in /databricks/python3/lib/python3.12/site-packages (from pinecone) (1.26.16)
# Requirement already satisfied: botocore<1.35.0,>=1.34.69 in /databricks/python3/lib/python3.12/site-packages (from boto3) (1.34.69)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /databricks/python3/lib/python3.12/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: packaging>=19.1 in /databricks/python3/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb) (0.46.1)
# Requirement already satisfied: anyio in /databricks/python3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /databricks/python3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /databricks/python3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.21.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /databricks/python3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /databricks/python3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /databricks/python3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (24.12.23)
# Requirement already satisfied: protobuf in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in /databricks/python3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.56.1->haystack-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from openai>=1.56.1->haystack-ai) (0.8.2)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.12/site-packages (from openai>=1.56.1->haystack-ai) (1.3.0)
# Requirement already satisfied: deprecated>=1.2.6 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-proto==1.31.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-util-http==0.52b0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from posthog!=3.12.0->haystack-ai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /databricks/python3/lib/python3.12/site-packages (from posthog!=3.12.0->haystack-ai) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic->haystack-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /databricks/python3/lib/python3.12/site-packages (from pydantic->haystack-ai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests->haystack-ai) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /databricks/python3/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in /databricks/python3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /databricks/python3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /databricks/python3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->haystack-ai) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /databricks/python3/lib/python3.12/site-packages (from jsonschema->haystack-ai) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /databricks/python3/lib/python3.12/site-packages (from jsonschema->haystack-ai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /databricks/python3/lib/python3.12/site-packages (from jsonschema->haystack-ai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from jsonschema->haystack-ai) (0.10.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.5.0)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %pip install --upgrade nltk==3.9.1
# Out:
# Collecting nltk==3.9.1
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in /databricks/python3/lib/python3.12/site-packages (from nltk==3.9.1) (8.1.7)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.12/site-packages (from nltk==3.9.1) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /databricks/python3/lib/python3.12/site-packages (from nltk==3.9.1) (2023.10.3)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from nltk==3.9.1) (4.66.4)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.5 MB ? eta -:--:--
#    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/1.5 MB 5.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.5 MB 5.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━ 0.8/1.5 MB 6.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 1.2/1.5 MB 7.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.5/1.5 MB 8.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Not uninstalling nltk at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb443690-19bd-4b03-a5c1-fb4f3738d6f5
#     Can't uninstall 'nltk'. No files were found to uninstall.
# Successfully installed nltk-3.9.1
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import nltk
nltk.download('punkt', download_dir='/dbfs/mnt/nltk_data')
nltk.data.path.append('dbfs:/mnt/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to /dbfs/mnt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import boto3
from botocore.exceptions import ClientError, EndpointConnectionError
from haystack import Pipeline
from haystack.document_stores.types import DuplicatePolicy
from haystack_integrations.document_stores.chroma import ChromaDocumentStore
from haystack_integrations.components.retrievers.pinecone import PineconeEmbeddingRetriever
from haystack_integrations.document_stores.pinecone import PineconeDocumentStore
from haystack.components.converters import TextFileToDocument
from haystack.components.preprocessors import DocumentCleaner, DocumentSplitter, RecursiveDocumentSplitter
from haystack.components.embedders import OpenAIDocumentEmbedder, OpenAITextEmbedder
from haystack.components.writers import DocumentWriter
from haystack.components.builders import PromptBuilder, ChatPromptBuilder
from haystack.components.generators.chat import OpenAIChatGenerator
from haystack.dataclasses import ChatMessage
from haystack.components.converters import MarkdownToDocument
from haystack.dataclasses.byte_stream import ByteStream
import requests
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
def get_s3_client():
    try:
        s3_client = boto3.client(
        's3', 
        aws_access_key_id=os.getenv('AWS_ACCESS_KEY'), 
        aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'),
        region_name=os.getenv('AWS_REGION')  
        )
        return s3_client
    except:
        return -1
    
    
def read_markdown_from_s3(s3_client, year, qtr, file_url):
    bucket_name, aws_region = os.getenv('BUCKET_NAME') , os.getenv('AWS_REGION') 
    if bucket_name is None or aws_region is None:
        return -1
    try:
        tool_path=dbutils.widgets.get("tool")
        file_name = file_url.split("/")[-1]
        response = s3_client.get_object(Bucket=bucket_name, Key=f'{year}/{qtr}/{tool_path}/{file_name}')
        markdown_content = response["Body"].read()  # Decode bytes to string .decode("utf-8")           
        return markdown_content, file_url
    except ClientError as e:
        if e.response['Error']['Code'] == "NoSuchKey":
            print("Error: The specified file does not exist.")
        else:
            print(f"ClientError: {e}")
        return -1
    except EndpointConnectionError as e:
        print("Error: Could not connect to the S3 endpoint. Check your configuration.")
        return -2
    except Exception as e:
        print(f"Unexpected error occurred: {e}")
        return -999

# %%
response = requests.get('https://rag-pipeline-data.s3.us-east-2.amazonaws.com/metadata/metadata_s3url.json')
metadata = response.json()

# %%
print(dbutils.widgets.get("tool"))

# %%
markdown_streams=[]
for year, metadata_value in metadata.items():
    for qtr, tool in metadata_value.items():
        file_name = tool[dbutils.widgets.get("tool")]
        markdown_bytes = read_markdown_from_s3(get_s3_client(), year, qtr, file_name)[0]
        markdown_stream = ByteStream(data=markdown_bytes, mime_type="text/markdown",meta={'year':year, 'qtr':qtr})
        markdown_streams.append(markdown_stream)

# %%
pinecone_document_store_cs1 = PineconeDocumentStore(index="nvidia-vectors", namespace="nvidia_cs_1", dimension=1536)
pinecone_document_store_cs2 = PineconeDocumentStore(index="nvidia-vectors", namespace="nvidia_cs_2", dimension=1536)
pinecone_document_store_cs3 = PineconeDocumentStore(index="nvidia-vectors", namespace="nvidia_cs_3", dimension=1536)

chroma_document_store_cs1 = ChromaDocumentStore(host="34.31.232.10", port="8000", collection_name="nvidia_cs_1")
chroma_document_store_cs2 = ChromaDocumentStore(host="34.31.232.10", port="8000", collection_name="nvidia_cs_2")
chroma_document_store_cs3 = ChromaDocumentStore(host="34.31.232.10", port="8000", collection_name="nvidia_cs_3")

converter = MarkdownToDocument()
cleaner = DocumentCleaner()
splitter_cs1 = DocumentSplitter(split_by="sentence", split_length=5)
splitter_cs2=RecursiveDocumentSplitter(
        split_length=400,
        split_overlap=40,
        split_unit="word",
        separators=["\n\n", "\n", "sentence", " "])
splitter_cs3=RecursiveDocumentSplitter(
        split_length=1200,
        split_overlap=120,
        split_unit="char",
        separators=["\n\n", "\n", "sentence", " "])

embedder_cs1 = OpenAIDocumentEmbedder(model="text-embedding-3-small", meta_fields_to_embed=["year", "qtr"], dimensions=1536)
embedder_cs2 = OpenAIDocumentEmbedder(model="text-embedding-3-small", meta_fields_to_embed=["year", "qtr"], dimensions=1536)
embedder_cs3 = OpenAIDocumentEmbedder(model="text-embedding-3-small", meta_fields_to_embed=["year", "qtr"], dimensions=1536)

pinecone_writer_cs1 = DocumentWriter(pinecone_document_store_cs1, DuplicatePolicy.OVERWRITE )
pinecone_writer_cs2 = DocumentWriter(pinecone_document_store_cs2, DuplicatePolicy.OVERWRITE )
pinecone_writer_cs3 = DocumentWriter(pinecone_document_store_cs3, DuplicatePolicy.OVERWRITE )

chroma_writer_cs1 = DocumentWriter(chroma_document_store_cs1, DuplicatePolicy.OVERWRITE)
chroma_writer_cs2 = DocumentWriter(chroma_document_store_cs2, DuplicatePolicy.OVERWRITE)
chroma_writer_cs3 = DocumentWriter(chroma_document_store_cs3, DuplicatePolicy.OVERWRITE)

indexing_pipeline = Pipeline()
indexing_pipeline.add_component("converter", converter)
indexing_pipeline.add_component("cleaner", cleaner)
indexing_pipeline.add_component("splitter_cs1", splitter_cs1)
indexing_pipeline.add_component("splitter_cs2", splitter_cs2)
indexing_pipeline.add_component("splitter_cs3", splitter_cs3)
indexing_pipeline.add_component("embedder_cs1", embedder_cs1)
indexing_pipeline.add_component("embedder_cs2", embedder_cs2)
indexing_pipeline.add_component("embedder_cs3", embedder_cs3)

indexing_pipeline.connect("converter.documents", "cleaner.documents")
indexing_pipeline.connect("cleaner.documents", "splitter_cs1.documents")
indexing_pipeline.connect("cleaner.documents", "splitter_cs2.documents")
indexing_pipeline.connect("cleaner.documents", "splitter_cs3.documents")
indexing_pipeline.connect("splitter_cs1.documents", "embedder_cs1.documents")
indexing_pipeline.connect("splitter_cs2.documents", "embedder_cs2.documents")
indexing_pipeline.connect("splitter_cs3.documents", "embedder_cs3.documents")

data=indexing_pipeline.run(data={"sources": markdown_streams})
# Out:
# WARNING:haystack.components.preprocessors.sentence_tokenizer:No abbreviations file found for en. Using default abbreviations.
# WARNING:haystack.components.preprocessors.sentence_tokenizer:No abbreviations file found for en. Using default abbreviations.
# WARNING:haystack.components.preprocessors.sentence_tokenizer:No abbreviations file found for en. Using default abbreviations.
#
#
# Converting markdown files to Documents:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Converting markdown files to Documents: 100%|██████████| 1/1 [00:00<00:00,  2.72it/s]
#
#
# Calculating embeddings: 0it [00:00, ?it/s]
#
# Calculating embeddings: 1it [00:02,  2.89s/it]
#
# Calculating embeddings: 2it [00:05,  2.58s/it]
#
# Calculating embeddings: 3it [00:07,  2.64s/it]
#
# Calculating embeddings: 4it [00:10,  2.60s/it]
#
# Calculating embeddings: 5it [00:12,  2.49s/it]
#
# Calculating embeddings: 6it [00:15,  2.45s/it]
#
# Calculating embeddings: 7it [00:17,  2.46s/it]
#
# Calculating embeddings: 8it [00:20,  2.62s/it]
#
# Calculating embeddings: 9it [00:22,  2.51s/it]
#
# Calculating embeddings: 10it [00:25,  2.51s/it]
#
# Calculating embeddings: 11it [00:28,  2.68s/it]
#
# Calculating embeddings: 12it [00:30,  2.59s/it]
#
# Calculating embeddings: 13it [00:33,  2.57s/it]
#
#
# Calculating embeddings: 0it [00:00, ?it/s]
#
# Calculating embeddings: 1it [00:02,  2.93s/it]
#
# Calculating embeddings: 2it [00:05,  2.80s/it]
#
# Calculating embeddings: 3it [00:08,  2.63s/it]
#
# Calculating embeddings: 4it [00:10,  2.62s/it]
#
# Calculating embeddings: 5it [00:12,  2.50s/it]
#
# Calculating embeddings: 6it [00:15,  2.40s/it]
#
# Calculating embeddings: 7it [00:17,  2.34s/it]
#
# Calculating embeddings: 8it [00:19,  2.34s/it]
#
# Calculating embeddings: 9it [00:22,  2.33s/it]
#
# Calculating embeddings: 10it [00:23,  2.38s/it]
#
#
# Calculating embeddings: 0it [00:00, ?it/s]
#
# Calculating embeddings: 1it [00:02,  2.16s/it]
#
# Calculating embeddings: 2it [00:04,  2.25s/it]
#
# Calculating embeddings: 3it [00:06,  2.31s/it]
#
# Calculating embeddings: 4it [00:08,  2.23s/it]
#
# Calculating embeddings: 5it [00:11,  2.38s/it]
#
# Calculating embeddings: 6it [00:13,  2.35s/it]
#
# Calculating embeddings: 7it [00:16,  2.37s/it]
#
# Calculating embeddings: 8it [00:18,  2.23s/it]
#
# Calculating embeddings: 9it [00:23,  3.27s/it]
#
# Calculating embeddings: 10it [00:25,  2.90s/it]
#
# Calculating embeddings: 11it [00:29,  3.00s/it]
#
# Calculating embeddings: 12it [00:31,  2.79s/it]
#
# Calculating embeddings: 13it [00:33,  2.52s/it]
#
# Calculating embeddings: 14it [00:35,  2.42s/it]
#
# Calculating embeddings: 15it [00:37,  2.30s/it]
#
# Calculating embeddings: 16it [00:39,  2.32s/it]
#
# Calculating embeddings: 17it [00:42,  2.29s/it]
#
# Calculating embeddings: 18it [00:44,  2.41s/it]
#
# Calculating embeddings: 19it [00:47,  2.45s/it]
#
# Calculating embeddings: 20it [00:50,  2.53s/it]
#
# Calculating embeddings: 21it [00:52,  2.40s/it]
#
# Calculating embeddings: 22it [00:54,  2.35s/it]
#
# Calculating embeddings: 23it [00:56,  2.38s/it]
#
# Calculating embeddings: 24it [00:58,  2.31s/it]
#
# Calculating embeddings: 25it [01:01,  2.24s/it]
#
# Calculating embeddings: 26it [01:04,  2.54s/it]
#
# Calculating embeddings: 27it [01:07,  2.83s/it]
#
# Calculating embeddings: 28it [01:09,  2.48s/it]
# [Trace(request_id=tr-b49492776b2a44cd92dda35f9740c6fc), Trace(request_id=tr-c0051f5ba1e145cd861f30db25fa94a1), Trace(request_id=tr-b6ff5a2309e24dc68bf48bf0232ee69a), Trace(request_id=tr-77dd1cc217534d0da1e8e4a8f1ff2be3), Trace(request_id=tr-0576f68231684e9f8be51720c01f8469), Trace(request_id=tr-7e9c1cab790949a0ade3d62012564f1f), Trace(request_id=tr-32a1d3a133e64b9393b666709d098462), Trace(request_id=tr-48605a0c40ff4e4d90f9427e5f762f1e), Trace(request_id=tr-512412d0f65e4d6e87d09291caa214d0), Trace(request_id=tr-ad25cbb07414454bbf1e1cafacaafe6c)]

# %%
docs=[]
for doc in data['embedder_cs1']['documents']:
    if '_split_overlap' in doc.meta:
        doc.meta.pop('_split_overlap')
    if doc.embedding:
        docs.append(doc)
pinecone_document_store_cs1.write_documents(docs)
# Out:
# Upserted vectors:   0%|          | 0/397 [00:00<?, ?it/s]
# 397

# %%
docs=[]
for doc in data['embedder_cs2']['documents']:
    if '_split_overlap' in doc.meta:
        doc.meta.pop('_split_overlap')
    if doc.embedding:
        docs.append(doc)
pinecone_document_store_cs2.write_documents(docs)
# Out:
# Upserted vectors:   0%|          | 0/290 [00:00<?, ?it/s]
# 290

# %%
docs=[]
for doc in data['embedder_cs3']['documents']:
    if '_split_overlap' in doc.meta:
        doc.meta.pop('_split_overlap')
    if doc.embedding:
        docs.append(doc)
pinecone_document_store_cs3.write_documents(docs)
# Out:
# Upserted vectors:   0%|          | 0/882 [00:00<?, ?it/s]
# 882

# %%
docs=[]
for doc in data['embedder_cs1']['documents']:
    if '_split_overlap' in doc.meta:
        doc.meta.pop('_split_overlap')
    if doc.embedding:
        docs.append(doc)
chroma_document_store_cs1.write_documents(docs)
# Out:
# 397

# %%
docs=[]
for doc in data['embedder_cs2']['documents']:
    if '_split_overlap' in doc.meta:
        doc.meta.pop('_split_overlap')
    if doc.embedding:
        docs.append(doc)
chroma_document_store_cs2.write_documents(docs)
# Out:
# 290

# %%
docs=[]
for doc in data['embedder_cs3']['documents']:
    if '_split_overlap' in doc.meta:
        doc.meta.pop('_split_overlap')
    if doc.embedding:
        docs.append(doc)
chroma_document_store_cs3.write_documents(docs)
# Out:
# 882
